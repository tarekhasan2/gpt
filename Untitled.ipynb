# %%
import pandas as pd

# %%
df = pd.read_csv('hotel_output.csv')
df.head()
# Out:
#    hotel_id                                               name  \
# 0  13836621           Millennium Hotel Paris Charles de Gaulle
# 1  10284308                    ibis budget Nanterre La Defense
# 2  10265216                     ibis budget Meudon Paris Ouest
# 3  27877978                                        Avalon Cosy
# 4    142941  Premiere Classe Roissy - Aeroport Charles De G...
#
#                                              address      price  \
# 0  2, Allée du Verger, Charles de Gaulle Airport,...  from $ 68
# 1  38 avenue Georges Clémenceau, La Defense, Pari...  from $ 93
# 2  3 bis rue de Paris, Issy-Les-Moulineaux, Paris...        NaN
# 3  28 rue de Dunkerque, 10th - Gare du Nord, Pari...        NaN
# 4  15 Allée du Verger, Charles de Gaulle Airport,...  from $ 81
#
#    overall_rating      total_review review_catagory  cleanliness_rating  \
# 0             NaN   From 17 reviews            Good                 7.3
# ...

# %%
hotel_df = df.dropna()
hotel_df.head()
# Out:
#     hotel_id                                               name  \
# 4     142941  Premiere Classe Roissy - Aeroport Charles De G...
# 7      60665                     Best Western Plus Paris Roissy
# 8      50463                 Ibis Styles Paris Roissy Cdg Hotel
# 9     445635              Premiere Classe Paris Montreuil Hotel
# 14    171914   Royal Regency Paris Vincennes by Diamond Resorts
#
#                                               address       price  \
# 4   15 Allée du Verger, Charles de Gaulle Airport,...   from $ 81
# 7   4 Allee du Verger, Charles de Gaulle Airport, ...  from $ 103
# 8   2 Avenue Heinz Gloor, Charles de Gaulle Airpor...  from $ 102
# 9   64, rue Jean Lolive, Montreuil, Paris, France,...   from $ 86
# 14  69/71, rue Defrance, Vincennes, Paris, France,...  from $ 151
#
#     overall_rating      total_review review_catagory  cleanliness_rating  \
# 4              7.8  From 213 reviews       Very good                 8.1
# ...

# %%
hotel_df = hotel_df[:1]
hotel_df = hotel_df[['hotel_id', 'name', 'address', 'price', 'facilitie_features', 'total_review', 
                     'overall_rating', 'review_catagory', 'free_wifi', 'fitness_center', 'swimming_pool', 
                     'airport_transfer', 'car_parking', 'free_breakfast']]
hotel_df.head(1)
# Out:
#    hotel_id                                               name  \
# 4    142941  Premiere Classe Roissy - Aeroport Charles De G...
#
#                                              address      price  \
# 4  15 Allée du Verger, Charles de Gaulle Airport,...  from $ 81
#
#                                   facilitie_features      total_review  \
# 4  english, arabic, chinese [cantonese], french, ...  From 213 reviews
#
#    overall_rating review_catagory  free_wifi  fitness_center  swimming_pool  \
# 4             7.8       Very good       True           False          False
#
#    airport_transfer  car_parking  free_breakfast
# 4              True         True           False

# %%
hotel_df['context'] = hotel_df.name + "\n" + hotel_df.facilitie_features
hotel_df.head(1)
# Out:
#    hotel_id                                               name  \
# 4    142941  Premiere Classe Roissy - Aeroport Charles De G...
#
#                                              address      price  \
# 4  15 Allée du Verger, Charles de Gaulle Airport,...  from $ 81
#
#                                   facilitie_features      total_review  \
# 4  english, arabic, chinese [cantonese], french, ...  From 213 reviews
#
#    overall_rating review_catagory  free_wifi  fitness_center  swimming_pool  \
# 4             7.8       Very good       True           False          False
#
#    airport_transfer  car_parking  free_breakfast  \
# 4              True         True           False
#
#                                              context
# 4  Premiere Classe Roissy - Aeroport Charles De G...

# %%
import openai
API_KEY = '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'

# openai.organization = "org-4wrRVFemttSaxaEfdWVbWhPt"
openai.api_key = API_KEY

#def get_questions(context):

prompt_com = ''
for index, context in hotel_df.iterrows():    
    list_    = []
    name     = context['name']
    features = context['facilitie_features']
    address  = context['address']
    price    = context['price']
    cetagory = context['review_catagory']
    price_prompt    = {"prompt": f"What is the starting price of {name} per night?", "completion": f"the starting price of {name} per night is {price}"}
    address_prompt  = {"prompt": f"What is the address of {name}?", "completion": f"The address of {name} is {address}"}
    cetagory_prompt = {"prompt": f"Is {name} a good hotel?", "completion": f"{name} is a {cetagory} hotel"}

    
    queation_context = []
    #queation_context = [c_price, c_address, c_cetagory]
    
    features_separator = features.split(',')
    
       
    
    for a in features_separator:
        feature_context = f"'{name}' hotel have'{a}'"
        queation_context.append(feature_context)
    
    for q_context in queation_context[10:15]:      
        try:
            #print(f"Write questions based on the text below\n\nText: {q_context}\n\nQuestions:\n1.")
            response = openai.Completion.create(
                engine="davinci-instruct-beta-v3",
                prompt=f"Write questions based on the text below\n\nText: {q_context}\n\nQuestions:\n1.",
                temperature=0.6,
                max_tokens=100,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0,
                stop=["\n\n"]
            )
            question_prompt = response['choices'][0]['text'].split('2. ')[0]
            print(question_prompt)
        except:
            None
        
        try:
            #print(f"Write answer based on the text below\n\nText: {q_context}\n\nQuestions:\n{question_prompt}\n\nAnswers:\n1.")
            response = openai.Completion.create(
                engine="davinci-instruct-beta-v3",
                prompt=f"Write answer based on the text below\n\nText: {q_context}\n\nQuestions:\n{question_prompt}\n\nAnswers:\n1.",
                temperature=1,
                max_tokens=100,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0,
                stop=["\n\n"]
            )
            answer_prompt = response['choices'][0]['text'].split('2. ')[0]
            print(answer_prompt)
        except:
            print('Not found')
            
            
        x = {"prompt":question_prompt, "completion": answer_prompt}
        prompt_com = prompt_com + str(x) + '\n'

        
#x = hotel_df.apply(get_questions, axis=1)
# Out:
#  What type of services does the hotel offer?
#
#
#  What is the name of the hotel?
#
#  The name of the hotel is 'Premiere Classe Roissy - Aeroport Charles De Gaulle'.
#
#  What type of products do Premiere Classe Roissy - Aeroport Charles De Gaulle hotel use for cleaning?
#
# Premiere Classe Roissy - Aeroport Charles De Gaulle hotel use anti-viral cleaning products.
#  What is the name of the hotel?
#
#  The name of the hotel is Premiere Classe Roissy - Aeroport Charles De Gaulle.
#
#  What is the name of the hotel?
#
#  Premiere Classe Roissy - Aeroport Charles De Gaulle

# %%
print(hotel_df['context'])
# Out:
# 4     Premiere Classe Roissy - Aeroport Charles De G...
# 7     Best Western Plus Paris Roissy\nenglish, hindi...
# 8     Ibis Styles Paris Roissy Cdg Hotel\nenglish, a...
# 9     Premiere Classe Paris Montreuil Hotel\nenglish...
# 14    Royal Regency Paris Vincennes by Diamond Resor...
# Name: context, dtype: object

# %%
# Out:
# 1. The distance from the hotel to the nearest airport is 17.7 km.
# 2. The distance from the hotel to the nearest metro station is 1.3 km.
# 3. The distance from the hotel to the nearest shopping centre is 1.4 km.
# 4. The distance from the hotel to the nearest tourist attraction is 20.8 km.
# 5. The distance from the hotel to the nearest restaurant is 150 m.
# 6. The distance from the hotel to the nearest bar is 490 m.
# 7. The distance from the hotel to the nearest casino is 1.4 km.
# 8. The distance from the hotel to the nearest nightclub is 970 m.
# 9. The distance from the hotel to the nearest hospital is 1.4 km.
# 10. The distance from the hotel to the nearest pharmacy is 490 m.

# %%
hotel_df.head(2)
# Out:
#    hotel_id                                               name  \
# 0    142941  Premiere Classe Roissy - Aeroport Charles De G...
# 1     60665                     Best Western Plus Paris Roissy
#
#                                              address       price  \
# 0  15 Allée du Verger, Charles de Gaulle Airport,...   from $ 81
# 1  4 Allee du Verger, Charles de Gaulle Airport, ...  from $ 103
#
#                                   facilitie_features      total_review  \
# 0  english, arabic, chinese [cantonese], french, ...  From 213 reviews
# 1  english, hindi, italian, portuguese, romanian,...   From 51 reviews
#
#    overall_rating review_catagory  free_wifi  fitness_center  swimming_pool  \
# 0             7.8       Very good       True           False          False
# 1             7.7       Very good       True            True          False
#
#    airport_transfer  car_parking  free_breakfast  \
# 0              True         True           False
# ...
